# %%
# !pip install pandas

# %%
import pandas as pd

# %%
dir(pd)
# Out:
# ['ArrowDtype',
#  'BooleanDtype',
#  'Categorical',
#  'CategoricalDtype',
#  'CategoricalIndex',
#  'DataFrame',
#  'DateOffset',
#  'DatetimeIndex',
#  'DatetimeTZDtype',
#  'ExcelFile',
#  'ExcelWriter',
#  'Flags',
#  'Float32Dtype',
#  'Float64Dtype',
#  'Grouper',
#  'HDFStore',
#  'Index',
#  'IndexSlice',
#  'Int16Dtype',
#  'Int32Dtype',
#  'Int64Dtype',
#  'Int8Dtype',
#  'Interval',
#  'IntervalDtype',
#  'IntervalIndex',
#  'MultiIndex',
#  'NA',
#  'NaT',
#  'NamedAgg',
#  'Period',
#  'PeriodDtype',
#  'PeriodIndex',
#  'RangeIndex',
#  'Series',
#  'SparseDtype',
#  'StringDtype',
#  'Timedelta',
#  'TimedeltaIndex',
#  'Timestamp',
#  'UInt16Dtype',
#  'UInt32Dtype',
#  'UInt64Dtype',
#  'UInt8Dtype',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__docformat__',
#  '__file__',
#  '__git_version__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__version__',
#  '_config',
#  '_is_numpy_dev',
#  '_libs',
# ...

# %%
# csv-> Comma Separated value
df=pd.read_csv('Salaries.csv')

# %%
# To check Number of Rows and Columns
df.shape
# Out:
# (78, 6)

# %%
# TO display information of a dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 78 entries, 0 to 77
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   rank        78 non-null     object
#  1   discipline  78 non-null     object
#  2   phd         76 non-null     float64
#  3   service     78 non-null     int64
#  4   sex         78 non-null     object
#  5   salary      76 non-null     float64
# dtypes: float64(2), int64(1), object(3)
# memory usage: 3.8+ KB

# %%
df.describe()
# Out:
#              phd    service         salary
# count  76.000000  78.000000      76.000000
# mean   19.605263  15.051282  108003.355263
# std    12.508215  12.139768   28525.350088
# min     1.000000   0.000000   57800.000000
# 25%    10.000000   5.250000   87250.000000
# 50%    18.500000  14.500000  104671.000000
# 75%    27.250000  20.750000  127077.750000
# max    56.000000  51.000000  186960.000000

# %%
# To know the dimensions
df.ndim
# Out:
# 2

# %%
# To Know the Columns
df.columns.to_list()
# Out:
# ['rank', 'discipline', 'phd', 'service', 'sex', 'salary']

# %%
df['discipline'].head()
# Out:
# 0    B
# 1    A
# 2    A
# 3    A
# 4    B
# Name: discipline, dtype: object

# %%
# DIsplay first 5 rows
df.head(5)
# Out:
#    rank discipline   phd  service   sex    salary
# 0  Prof          B  56.0       49  Male  186960.0
# 1  Prof          A  12.0        6  Male   93000.0
# 2  Prof          A  23.0       20  Male  110515.0
# 3  Prof          A  40.0       31  Male  131205.0
# 4  Prof          B  20.0       18  Male  104800.0

# %%
# Display Last 5 rows
df.tail(5)
# Out:
#          rank discipline   phd  service     sex    salary
# 73       Prof          B  18.0       10  Female  105450.0
# 74  AssocProf          B  19.0        6  Female  104542.0
# 75       Prof          B  17.0       17  Female  124312.0
# 76       Prof          A  28.0       14  Female  109954.0
# 77       Prof          A  23.0       15  Female  109646.0

# %%
# Display a Sample Randomly
df.sample()
# Out:
#     rank discipline   phd  service     sex   salary
# 63  Prof          A  29.0       27  Female  91000.0

# %%
# Display 3 Sample Randomly
df.sample(3)
# Out:
#          rank discipline   phd  service     sex    salary
# 58       Prof          B  36.0       26  Female  144651.0
# 47  AssocProf          B  11.0       11  Female  103613.0
# 73       Prof          B  18.0       10  Female  105450.0

# %%
len(df.columns)
# Out:
# 6

# %%
# Exploratory Data Analytics

# %%
#Display any Column
df['rank']
# Out:
# 0          Prof
# 1          Prof
# 2          Prof
# 3          Prof
# 4          Prof
#         ...
# 73         Prof
# 74    AssocProf
# 75         Prof
# 76         Prof
# 77         Prof
# Name: rank, Length: 78, dtype: object

# %%
df['discipline']
# Out:
# 0     B
# 1     A
# 2     A
# 3     A
# 4     B
#      ..
# 73    B
# 74    B
# 75    B
# 76    A
# 77    A
# Name: discipline, Length: 78, dtype: object

# %%
df
# Out:
#          rank discipline   phd  service     sex    salary
# 0        Prof          B  56.0       49    Male  186960.0
# 1        Prof          A  12.0        6    Male   93000.0
# 2        Prof          A  23.0       20    Male  110515.0
# 3        Prof          A  40.0       31    Male  131205.0
# 4        Prof          B  20.0       18    Male  104800.0
# ..        ...        ...   ...      ...     ...       ...
# 73       Prof          B  18.0       10  Female  105450.0
# 74  AssocProf          B  19.0        6  Female  104542.0
# 75       Prof          B  17.0       17  Female  124312.0
# 76       Prof          A  28.0       14  Female  109954.0
# 77       Prof          A  23.0       15  Female  109646.0
#
# [78 rows x 6 columns]

# %%
# TO display entire Dataset in one Place
print(df.to_string())
# Out:
#          rank discipline   phd  service     sex    salary
# 0        Prof          B  56.0       49    Male  186960.0
# 1        Prof          A  12.0        6    Male   93000.0
# 2        Prof          A  23.0       20    Male  110515.0
# 3        Prof          A  40.0       31    Male  131205.0
# 4        Prof          B  20.0       18    Male  104800.0
# 5        Prof          A  20.0       20    Male  122400.0
# 6   AssocProf          A  20.0       17    Male   81285.0
# 7        Prof          A  18.0       18    Male       NaN
# 8        Prof          A  29.0       19    Male   94350.0
# 9        Prof          A  51.0       51    Male   57800.0
# 10       Prof          B  39.0       33    Male  128250.0
# 11       Prof          B  23.0       23    Male  134778.0
# 12   AsstProf          B   1.0        0    Male   88000.0
# 13       Prof          B   NaN       33    Male  162200.0
# 14       Prof          B  25.0       19    Male  153750.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 78 entries, 0 to 77
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   rank        78 non-null     object
#  1   discipline  78 non-null     object
#  2   phd         76 non-null     float64
#  3   service     78 non-null     int64
#  4   sex         78 non-null     object
#  5   salary      76 non-null     float64
# dtypes: float64(2), int64(1), object(3)
# memory usage: 3.8+ KB

# %%
# The Data type written as object can be performed as Classification
# Columns are also known as Features
# THey are of two types one is Dependent and Independent

# %%
# How many Categories a Column Contain
df['rank'].unique()
# Out:
# array(['Prof', 'AssocProf', 'AsstProf'], dtype=object)

# %%
df['discipline'].unique()
# Out:
# array(['B', 'A'], dtype=object)

# %%
df['sex'].unique()
# Out:
# array(['Male', 'Female'], dtype=object)

# %%
# THe Departmant has how many no. of Records
# Display how many candidates 
df['discipline'].value_counts()
# Out:
# discipline
# B    42
# A    36
# Name: count, dtype: int64

# %%
# Categorize the number of gender too!
df['sex'].value_counts()
# There are various methods to balance a data such as Data Augmentation
# Out:
# sex
# Male      39
# Female    39
# Name: count, dtype: int64

# %%
# TO display More than one column
df[['sex','rank','phd']]
# Out:
#        sex       rank   phd
# 0     Male       Prof  56.0
# 1     Male       Prof  12.0
# 2     Male       Prof  23.0
# 3     Male       Prof  40.0
# 4     Male       Prof  20.0
# ..     ...        ...   ...
# 73  Female       Prof  18.0
# 74  Female  AssocProf  19.0
# 75  Female       Prof  17.0
# 76  Female       Prof  28.0
# 77  Female       Prof  23.0
#
# [78 rows x 3 columns]

# %%
# Display maximum Salary
df['salary'].max()
# Out:
# 186960.0

# %%
#Display Minimum Salary
df['salary'].min()
# Out:
# 57800.0

# %%
df['salary'].mean()
# Out:
# 108003.3552631579

# %%
# Display Faculty who are getting Salary above average salary
df[df['salary']>df['salary'].mean()][['rank', 'discipline', 'phd', 'service', 'sex', 'salary']]
# Out:
#          rank discipline   phd  service     sex    salary
# 0        Prof          B  56.0       49    Male  186960.0
# 2        Prof          A  23.0       20    Male  110515.0
# 3        Prof          A  40.0       31    Male  131205.0
# 5        Prof          A  20.0       20    Male  122400.0
# 10       Prof          B  39.0       33    Male  128250.0
# 11       Prof          B  23.0       23    Male  134778.0
# 13       Prof          B   NaN       33    Male  162200.0
# 14       Prof          B  25.0       19    Male  153750.0
# 15       Prof          B  17.0        3    Male  150480.0
# 19       Prof          A  29.0       27    Male  150500.0
# 26       Prof          A  38.0       19    Male  148750.0
# 27       Prof          A  45.0       43    Male  155865.0
# 29       Prof          B  21.0       20    Male  123683.0
# 31       Prof          B  22.0       21    Male  155750.0
# 33       Prof          B  18.0       18    Male  120000.0
# ...

# %%
df[(df['salary']<df['salary'].mean()) & (df['sex']=='Female')][['rank', 'discipline', 'phd', 'service', 'sex', 'salary']]
# Out:
#          rank discipline   phd  service     sex    salary
# 41  AssocProf          A  13.0        8  Female   74830.0
# 42   AsstProf          B   4.0        2  Female   80225.0
# 43   AsstProf          B   5.0        0  Female   77000.0
# 46   AsstProf          B  11.0        3  Female   74692.0
# 47  AssocProf          B  11.0       11  Female  103613.0
# 50   AsstProf          B  10.0        5  Female   97032.0
# 52       Prof          A  12.0        0  Female  105000.0
# 53   AsstProf          A   5.0        3  Female   73500.0
# 54  AssocProf          A  25.0       22  Female   62884.0
# 55   AsstProf          A   2.0        0  Female   72500.0
# 56  AssocProf          A  10.0        8  Female   77500.0
# 57   AsstProf          A   3.0        1  Female   72500.0
# 59  AssocProf          B  12.0       10  Female  103994.0
# 60   AsstProf          B   3.0        3  Female   92000.0
# 61  AssocProf          B  13.0       10  Female  103750.0
# ...

# %%
# Create a  Dictionary for Student with 2 keys as Semester[list of 6 Semester] and Subject(6 Subjects) 
std={1:['sub1','sub1','sub1','sub1','sub1','sub1'],
     2:['sub2','sub2','sub2','sub2','sub2','sub2'],
     3:['sub3','sub3','sub3','sub3','sub3','sub3'],
     4:['sub4','sub4','sub4','sub4','sub4','sub4'],
     5:['sub5','sub5','sub5','sub5','sub5','sub5']}

pd.DataFrame(std)
# Out:
#       1     2     3     4     5
# 0  sub1  sub2  sub3  sub4  sub5
# 1  sub1  sub2  sub3  sub4  sub5
# 2  sub1  sub2  sub3  sub4  sub5
# 3  sub1  sub2  sub3  sub4  sub5
# 4  sub1  sub2  sub3  sub4  sub5
# 5  sub1  sub2  sub3  sub4  sub5

# %%
std={'Semester':[1,2,3,4,5,6],
     'Subject':['phy','chem','bio','cpp','Java','NLP']}
pd.DataFrame(std)
# Out:
#    Semester Subject
# 0         1     phy
# 1         2    chem
# 2         3     bio
# 3         4     cpp
# 4         5    Java
# 5         6     NLP

# %%
dept=['cse','it','csce','etc','biotech']
dept_series=pd.Series(dept,index=['c','i','s','c','e'])
# pd.DataFrame(dept_series))
dept_series
# Out:
# c        cse
# i         it
# s       csce
# c        etc
# e    biotech
# dtype: object
